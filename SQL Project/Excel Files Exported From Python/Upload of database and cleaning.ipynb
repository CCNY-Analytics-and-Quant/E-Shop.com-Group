# %%
#UPLOADING PHASE
import pandas as pd
customerData=pd.read_csv(r"C:\Users\osamw\Documents\Python for Buiness Analytics\customer base data.csv")
orderBase=pd.read_csv(r"C:\Users\osamw\Documents\Python for Buiness Analytics\order base data.csv")
orderItems=pd.read_csv(r"C:\Users\osamw\Documents\Python for Buiness Analytics\order items data.csv")

productInfo=pd.read_csv(r"C:\Users\osamw\Documents\Python for Buiness Analytics\product info data.csv")
productInEng=pd.read_csv(r"C:\Users\osamw\Documents\Python for Buiness Analytics\product name translator data.csv")
reviewInfo=pd.read_csv(r"C:\Users\osamw\Documents\Python for Buiness Analytics\review data.csv")
sellerInfo=pd.read_csv(r"C:\Users\osamw\Documents\Python for Buiness Analytics\seller info data.csv")
zipCodeInfo=pd.read_csv(r"C:\Users\osamw\Documents\Python for Buiness Analytics\zipcode info data.csv")

# %%
display(customerData,orderBase,orderItems,productInfo,productInEng,reviewInfo,sellerInfo,zipCodeInfo)
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
CD=customerData.drop_duplicates(inplace = False)
OD=orderBase.drop_duplicates(inplace = False)
OI=orderItems.drop_duplicates(inplace = False)
PI=productInfo.drop_duplicates(inplace = False)
PrI=productInEng.drop_duplicates(inplace = False)
RI=reviewInfo.drop_duplicates(inplace = False)
SI=sellerInfo.drop_duplicates(inplace = False)
ZI=zipCodeInfo.drop_duplicates(inplace = False)
#check for duplicates
display(CD,OD,OI,PI,PrI,RI,SI,ZI)
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
#no duplicates were found

print(CD.loc[122])
#returns a row to show what a specific customers details are like
#display(customerData.loc[122]) also does the same as print()#
# Out:
# customer_id                 e32daa14dfa90eff675034dc7d462cf3
# customer_unique_id          52e57dd9218d99ea21b26f00c9151761
# customer_zip_code_prefix                               28909
# customer_city                                      cabo frio
# customer_state                                            RJ
# Name: 122, dtype: object

# %%
display(CD.loc[CD['customer_state']=='SP'])
CD.loc[customerData.customer_state == 'SP', 'customer_state'].count()
#both show how to fing how many customers where from the state of San Paulo, 
#the bottom one simply return the amount of instances (number of rows) it occured

# 41746/99441 is from San Paulo we can now use this
#to find out how many of our customers are from each state of brazil
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99432  f255d679c7c86c24ef4861320d5b7675  d111b06b6f3a2add0d2241325f65b5ca
# 99434  f5a0b560f9e9427792a88bec97710212  b3e53d18a997f27a3ffd16da497eaf58
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
display(customerData.loc[customerData['customer_state']=='SP'])
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99432  f255d679c7c86c24ef4861320d5b7675  d111b06b6f3a2add0d2241325f65b5ca
# 99434  f5a0b560f9e9427792a88bec97710212  b3e53d18a997f27a3ffd16da497eaf58
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
customerData.loc[customerData['customer_state']=='SP']
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99432  f255d679c7c86c24ef4861320d5b7675  d111b06b6f3a2add0d2241325f65b5ca
# 99434  f5a0b560f9e9427792a88bec97710212  b3e53d18a997f27a3ffd16da497eaf58
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
customerData.shape[0]
# Out:
# 99441

# %%
orderBase.loc[orderBase.order_id == "0607f0efea4b566f1eb8f7d3c2397320"]
# Out:
#                                order_id                       customer_id  \
# 40094  0607f0efea4b566f1eb8f7d3c2397320  a5fbb6579eacbeb02752a143bfe82405
#
#       order_status                date_approved                 date_shipped  \
# 40094    delivered  2018-03-06 09:55:47.0000000  2018-03-07 21:33:39.0000000
#
#                       date_arrived               date_estimated
# 40094  2018-03-09 23:36:47.0000000  2018-08-03 00:00:00.0000000

# %%
orderItems.loc[orderItems.order_id == "0607f0efea4b566f1eb8f7d3c2397320"]
# Out:
#                               order_id  order_item_id  \
# 2682  0607f0efea4b566f1eb8f7d3c2397320              1
# 2683  0607f0efea4b566f1eb8f7d3c2397320              2
#
#                             product_id                         seller_id  \
# 2682  952ef4ed720bf5d77f42712da90f2f49  903037660cf848a717166eb7a06d616e
# 2683  952ef4ed720bf5d77f42712da90f2f49  903037660cf848a717166eb7a06d616e
#
#               shipping_limit_date  price
# 2682  2018-03-13 09:55:47.0000000  62.99
# 2683  2018-03-13 09:55:47.0000000  62.99

# %%
payments.loc[payments.order_id=="0008288aa423d2a3f00fcb17cd7d8719"]
# Out:
#                                order_id  payment_sequential payment_type  \
# 85982  0008288aa423d2a3f00fcb17cd7d8719                   1       boleto
#
#        payment_installments  payment_value
# 85982                     1         126.54

# %%
reviewInfo.fillna('', inplace = True)
