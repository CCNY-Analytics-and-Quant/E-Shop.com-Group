# %%
#ideally this is to find a way to find how my money a specific product category generated
import pandas as pd
import pip
pip.main(["install","openpyxl"])
import openpyxl as xls

orderItems=pd.read_csv(r"C:\Users\osamw\Documents\Python for Buiness Analytics\order items data.csv")

productInfo=pd.read_csv(r"C:\Users\osamw\Documents\Python for Buiness Analytics\product info data.csv")
productInEng=pd.read_csv(r"C:\Users\osamw\Documents\Python for Buiness Analytics\product name translator data.csv")
orderBase=pd.read_csv(r"C:\Users\osamw\Documents\Python for Buiness Analytics\order base data.csv")
customerData=pd.read_csv(r"C:\Users\osamw\Documents\Python for Buiness Analytics\customer base data.csv")
display(productInfo,orderItems,productInEng,orderBase,customerData)
# Out:
# C:\JupyterLab\resources\jlab_server\lib\site-packages\_distutils_hack\__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...

# %%
#newCol1=[]
#newCol2=[]
#for num in range (32951) :
    #newCol1+=[orderItems.loc[orderItems.product_id==productInfo.iloc[num,0],'product_id'].count()]
#newCol1

# %%
#productInfo['number_of_purchases']=newCol1
display(productInfo)
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_photos_qty
# 0                     1.0
# ...

# %%
orderItems.loc[orderItems["product_id"] == "a0b7d5a992ccda646f2d34e418fff5a0"].count() #confirmation of values are in place
# Out:
# order_id               33
# order_item_id          33
# product_id             33
# seller_id              33
# shipping_limit_date    33
# price                  33
# dtype: int64

# %%
dftbm=orderItems.drop(columns=['order_item_id', 'seller_id','shipping_limit_date'])
newdf=pd.merge(productInfo,dftbm,on="product_id",how="left")
newdf=newdf.drop(columns='product_photos_qty')
newdf
# Out:
#                               product_id   product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5              perfumaria
# 1       3aa071139cb16b67ca9e5dea641aaa2f                   artes
# 2       96bd76ec8810374ed1b65e291975717f           esporte_lazer
# 3       cef67bcfe19066a932b7673e239eb23d                   bebes
# 4       9dc1a7de274444849c219cff195d0b71   utilidades_domesticas
# ...                                  ...                     ...
# 112645  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112646  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112647  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112648  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112649  106392145fca363410d287a815be6de4         cama_mesa_banho
#
#                                 order_id   price
# 0       e17e4f88e31525f7deef66779844ddce   10.91
# 1       5236307716393b7114b53ee991f36956  248.00
# ...

# %%
orderItems.loc[orderItems["product_id"] == "83808703fc0706a22e264b9d75f04a2e"]
#confirmation of values are in place
# Out:
#                                order_id  order_item_id  \
# 29026  420937423f0cb3d3fe689330b5d385a9              1
# 29027  420937423f0cb3d3fe689330b5d385a9              2
# 39538  59e88b7d3675e89aceaf86f372d3bc9a              1
# 39539  59e88b7d3675e89aceaf86f372d3bc9a              2
# 48515  6e4465d771f02e4fe335225de3c6c043              1
# 48516  6e4465d771f02e4fe335225de3c6c043              2
# 48517  6e4465d771f02e4fe335225de3c6c043              3
#
#                              product_id                         seller_id  \
# 29026  83808703fc0706a22e264b9d75f04a2e  4324dd16853115efb0fd9d0d131ba6f4
# 29027  83808703fc0706a22e264b9d75f04a2e  4324dd16853115efb0fd9d0d131ba6f4
# 39538  83808703fc0706a22e264b9d75f04a2e  4324dd16853115efb0fd9d0d131ba6f4
# 39539  83808703fc0706a22e264b9d75f04a2e  4324dd16853115efb0fd9d0d131ba6f4
# 48515  83808703fc0706a22e264b9d75f04a2e  4324dd16853115efb0fd9d0d131ba6f4
# 48516  83808703fc0706a22e264b9d75f04a2e  4324dd16853115efb0fd9d0d131ba6f4
# ...

# %%
productInfo.loc[productInfo["product_id"] == "83808703fc0706a22e264b9d75f04a2e"]
# Out:
#                              product_id   product_category_name  \
# 32949  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
#
#        product_photos_qty
# 32949                 2.0

# %%
newdf.loc[newdf["product_id"] == "83808703fc0706a22e264b9d75f04a2e"]
# Out:
#                               product_id   product_category_name  \
# 112642  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112643  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112644  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112645  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112646  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112647  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112648  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
#
#                                 order_id  price
# 112642  420937423f0cb3d3fe689330b5d385a9  39.71
# 112643  420937423f0cb3d3fe689330b5d385a9  39.71
# 112644  59e88b7d3675e89aceaf86f372d3bc9a  29.90
# 112645  59e88b7d3675e89aceaf86f372d3bc9a  29.90
# 112646  6e4465d771f02e4fe335225de3c6c043  29.90
# 112647  6e4465d771f02e4fe335225de3c6c043  29.90
# 112648  6e4465d771f02e4fe335225de3c6c043  29.90

# %%
display(newdf)
# Out:
#                               product_id   product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5              perfumaria
# 1       3aa071139cb16b67ca9e5dea641aaa2f                   artes
# 2       96bd76ec8810374ed1b65e291975717f           esporte_lazer
# 3       cef67bcfe19066a932b7673e239eb23d                   bebes
# 4       9dc1a7de274444849c219cff195d0b71   utilidades_domesticas
# ...                                  ...                     ...
# 112645  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112646  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112647  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112648  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112649  106392145fca363410d287a815be6de4         cama_mesa_banho
#
#                                 order_id   price
# 0       e17e4f88e31525f7deef66779844ddce   10.91
# 1       5236307716393b7114b53ee991f36956  248.00
# ...

# %%
orderBase
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status                date_approved                 date_shipped  \
# ...

# %%
dftbm2=orderBase.drop(columns=['order_status','date_shipped','date_arrived','date_estimated'])
dftbm2
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#                      date_approved
# 0      2017-10-02 11:07:15.0000000
# ...

# %%
newdfStates=pd.merge(newdf,dftbm2,on="order_id",how="left")
newdfStates
# Out:
#                               product_id   product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5              perfumaria
# 1       3aa071139cb16b67ca9e5dea641aaa2f                   artes
# 2       96bd76ec8810374ed1b65e291975717f           esporte_lazer
# 3       cef67bcfe19066a932b7673e239eb23d                   bebes
# 4       9dc1a7de274444849c219cff195d0b71   utilidades_domesticas
# ...                                  ...                     ...
# 112645  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112646  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112647  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112648  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112649  106392145fca363410d287a815be6de4         cama_mesa_banho
#
#                                 order_id   price  \
# 0       e17e4f88e31525f7deef66779844ddce   10.91
# 1       5236307716393b7114b53ee991f36956  248.00
# ...

# %%
print(newdfStates['price'].sum())
# Out:
# 13591643.7

# %%
customerData
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
dftbm3=customerData.drop(columns=['customer_unique_id', 'customer_city','customer_zip_code_prefix'])
dftbm3
# Out:
#                             customer_id customer_state
# 0      06b8999e2fba1a1fbc88172c00ba8bc7             SP
# 1      18955e83d337fd6b2def6b18a428ac77             SP
# 2      4e7b3e00288586ebd08712fdd0374a03             SP
# 3      b2b6027bc5c5109e529d4dc6358b12c3             SP
# 4      4f2d8ab171c80ec8364f7c12e35b23ad             SP
# ...                                 ...            ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f             SP
# 99437  e7b71a9017aa05c9a7fd292d714858e8             SP
# 99438  5e28dfe12db7fb50a4b2f691faecea5e             CE
# 99439  56b18e2166679b8a959d72dd06da27f9             RS
# 99440  274fa6071e5e17fe303b9748641082c8             SP
#
# [99441 rows x 2 columns]

# %%
newdfStates1=pd.merge(newdfStates,dftbm3,on="customer_id",how="left")
newdfStates1
# Out:
#                               product_id   product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5              perfumaria
# 1       3aa071139cb16b67ca9e5dea641aaa2f                   artes
# 2       96bd76ec8810374ed1b65e291975717f           esporte_lazer
# 3       cef67bcfe19066a932b7673e239eb23d                   bebes
# 4       9dc1a7de274444849c219cff195d0b71   utilidades_domesticas
# ...                                  ...                     ...
# 112645  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112646  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112647  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112648  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112649  106392145fca363410d287a815be6de4         cama_mesa_banho
#
#                                 order_id   price  \
# 0       e17e4f88e31525f7deef66779844ddce   10.91
# 1       5236307716393b7114b53ee991f36956  248.00
# ...

# %%
newdfStates1=pd.merge(newdfStates,dftbm3,on="customer_id",how="left")
newdfStates1
# Out:
#                               product_id   product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5              perfumaria
# 1       3aa071139cb16b67ca9e5dea641aaa2f                   artes
# 2       96bd76ec8810374ed1b65e291975717f           esporte_lazer
# 3       cef67bcfe19066a932b7673e239eb23d                   bebes
# 4       9dc1a7de274444849c219cff195d0b71   utilidades_domesticas
# ...                                  ...                     ...
# 112645  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112646  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112647  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112648  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 112649  106392145fca363410d287a815be6de4         cama_mesa_banho
#
#                                 order_id   price  \
# 0       e17e4f88e31525f7deef66779844ddce   10.91
# 1       5236307716393b7114b53ee991f36956  248.00
# ...

# %%
excelFile= pd.ExcelWriter('TopSellingProductsNew.xlsx')

newdf.to_excel(excelFile)

excelFile.save()

newdf.to_csv('TopSellingProductsNew.csv')

# %%
excelFile= pd.ExcelWriter('productcateg.xlsx')

productInEng.to_excel(excelFile)

excelFile.save()

productInEng.to_csv('productcateg.csv')

# %%
excelFile= pd.ExcelWriter('TopSellingProductsbyState.xlsx')

newdfStates1.to_excel(excelFile)

excelFile.save()

newdfStates1.to_csv('TopSellingProductsbyState.csv')
